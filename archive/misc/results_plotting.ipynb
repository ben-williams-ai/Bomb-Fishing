# %% [markdown]
# Todo:
# - fit style to figs in thesis. so bold fonts fofr axis titles, thicker axis lines, sort legends
# - figure out why bombing happend at 2am. is it rare occurences?
# - probs need some statistical model to see if there is a pattern? though im not sure if that really adds much value
# - aks agung if they haev any of the missing data gaps/to prioritise these.
# - make training performance plots?
# - write up!
# - Todo: 1) Make map with inse, use the bomb localisation code (add coords on axis). 2) plot bombs v augmented, use the exisitng files and fig from the global acoustic chapters code. 3) get auprc plot again (or put in but leave note to improve?). 4) copy mode architiecture from inference notebook into soemthign that cna maek model.
# - arch: remake. label myself in powerpoint. Labels each layer and have H, W, F optionals. Label dropout and flatten layers on lines.

# %%
import os
from datetime import datetime, timedelta, date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Global variables
# Base directory from environment
BASE_DIR = os.getenv("BASE_DIR")
if not BASE_DIR:
    raise ValueError("BASE_DIR must be set")

CSV_FOLDER: str = os.path.join(BASE_DIR, "bomb_fishing/data/mars_outputs")
BOMB_KEYWORDS = {"y", "Y", "yes", "bomb"} # keywords used by team to denote a bomb

# %% [markdown]
# ### Plot time series

# %%
def load_data_by_recorder(csv_folder: str, recorder_prefix: str) -> pd.DataFrame:
    """Load and concatenate CSV files for a given north/south recorder prefix.

    Args:
        csv_folder: Path to the folder containing CSV files.
        recorder_prefix: Prefix of files to load (e.g., 'north' or 'south').

    Returns:
        DataFrame with parsed 'datetime' and 'bomb_detected' columns.
    """
    file_list = [
        os.path.join(csv_folder, f)
        for f in os.listdir(csv_folder)
        if f.lower().startswith(recorder_prefix.lower()) and f.lower().endswith(".csv")
    ]
    if not file_list:
        raise FileNotFoundError(f"No CSV files found for region '{recorder_prefix}'.")
    df_list = [pd.read_csv(fp) for fp in file_list]
    df = pd.concat(df_list, ignore_index=True)
    # Parse datetime from File column
    df["datetime"] = (
        df["File"].str.replace(".WAV", "", regex=False)
        .apply(lambda x: datetime.strptime(x, "%Y%m%d_%H%M%S"))
    )
    # Flag bomb detections
    df["bomb_detected"] = (
        df["Bombs"].astype(str).str.lower().isin(BOMB_KEYWORDS)
    )
    return df


def aggregate_daily_counts(df: pd.DataFrame) -> (pd.Series, pd.Series):
    """Aggregate bomb detections and recording presence by day.

    Args:
        df: DataFrame with 'datetime' and 'bomb_detected'.

    Returns:
        Tuple of two Series indexed by date:
          - bombs_per_day: count of detections per day.
          - recordings_per_day: count of recordings per day.
    """
    df["date"] = df["datetime"].dt.date
    all_dates = pd.date_range(start=df["date"].min(), end=df["date"].max(), freq="D")
    bombs_count = df.loc[df["bomb_detected"]].groupby("date").size()
    recordings_count = df.groupby("date").size()
    bombs_count = bombs_count.reindex(all_dates.date, fill_value=0)
    recordings_count = recordings_count.reindex(all_dates.date, fill_value=0)
    bombs_count.index = pd.to_datetime(bombs_count.index)
    recordings_count.index = pd.to_datetime(recordings_count.index)
    return bombs_count, recordings_count


def find_gap_spans(recordings_count: pd.Series) -> list[tuple[date, date]]:
    """Identify contiguous spans of days with no recordings.

    Args:
        recordings_count: Series indexed by datetime, values are counts per day.

    Returns:
        List of (start_date, end_date) tuples for each gap.
    """
    gap_days = [d.date() for d, c in recordings_count.items() if c == 0]
    if not gap_days:
        return []
    gap_days_sorted = sorted(gap_days)
    spans = []
    start = prev = gap_days_sorted[0]
    for current in gap_days_sorted[1:]:
        if current == prev + timedelta(days=1):
            prev = current
        else:
            spans.append((start, prev))
            start = prev = current
    spans.append((start, prev))
    return spans

# %%
def plot_bomb_time_series(csv_folder: str) -> None:
    """Plot daily bomb counts with recording gaps shaded *between* bars."""
    recorders = ["north", "south"]
    fig, axes = plt.subplots(len(recorders), 1, sharex=True, figsize=(12, 8))
    colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]
    bar_width = 0.8                           # days
    half_width = bar_width / 2

    for ax, recorder, color in zip(axes, recorders, colors):
        df = load_data_by_recorder(csv_folder, recorder)
        bombs_count, recordings_count = aggregate_daily_counts(df)
        gap_spans = find_gap_spans(recordings_count)
        dates = bombs_count.index

        # Shade gaps *between* bars, inset by half_width days on each side:
        for start, end in gap_spans:
            ax.axvspan(
                start + timedelta(days=half_width),
                end + timedelta(days=1 - half_width),
                color="grey",
                alpha=0.3,
                zorder=0,
            )

        # Plot the double‐height “background” bars
        ax.bar(
            dates,
            bombs_count * 2,
            width=bar_width,
            color=color,
            alpha=0.3,
            label="Double bombs count",
            zorder=1,
        )
        # Plot the real counts on top
        ax.bar(
            dates,
            bombs_count,
            width=bar_width,
            color=color,
            label="Bombs count",
            zorder=2,
        )

        ax.set_title(f"{recorder.capitalize()} Daily Bomb Detections", fontweight="bold")
        ax.set_ylabel("Count per day", fontweight="bold")
        ax.legend()

    # Tidy up dates
    axes[-1].xaxis.set_major_locator(mdates.MonthLocator())
    axes[-1].xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
    fig.autofmt_xdate(rotation=45)
    plt.xlabel("Date")
    fig.tight_layout()
    plt.show()

plot_bomb_time_series(CSV_FOLDER)

# %%
# South-only daily bomb detections


# Parameters
recorder = "south"
bar_width = 1                    # in days
half_width = bar_width / 2
colours = plt.rcParams["axes.prop_cycle"].by_key()["color"]
colour = colours[1] # gets that nice contrasting ornage colour

# Load & aggregate
df = load_data_by_recorder(CSV_FOLDER, recorder)
bombs_count, recordings_count = aggregate_daily_counts(df)
gaps = find_gap_spans(pd.Series(recordings_count.values, index=bombs_count.index))

# Plot setup
fig, ax = plt.subplots(figsize=(9, 4))

# Shade gaps *between* bars
for start, end in gaps:
    ax.axvspan(
        start + timedelta(days=half_width),
        end   + timedelta(days=1 - half_width),
        color="grey",   # use 'color', not 'colour'
        alpha=0.3,
        zorder=0,
    )

# Actual bomb counts
ax.bar(
    bombs_count.index,
    bombs_count.values,
    width=bar_width,
    color=colour,    # use 'color'
    label="Verified count (50% duty cycle)",
    zorder=2,
)

# Double-height “background” bars
ax.bar(
    bombs_count.index,
    bombs_count.values * 2,
    width=bar_width,
    color=colour,    # use 'color'
    alpha=0.3,
    label="Projected count (100% duty cycle)",
    zorder=1,
)


# Formatting
ax.margins(x=0) # remove extra white space on left/right

#ax.set_title("South Daily Bomb Detections")
ax.set_ylabel("Blasts per day", fontweight="bold")
# Horizontal legend below the plot
ax.legend(
    ncol=2,
    loc="upper center",
    bbox_to_anchor=(0.5, -0.4),
    frameon=False,
    columnspacing=8,             # increase this to create more horizontal gap
)
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
fig.autofmt_xdate(rotation=45)
plt.xlabel("Date", fontweight="bold")
plt.tight_layout()
save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", f"barplot.png")
plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()

# %% [markdown]
# ### GAM for exploring patterns overtime
# To test whether there are any trends in bomb fishig activity overtime we fit a GAM.
# What we do:
# 1. Load and preprocess the data
# 2. Checked for overdispersion and found it to be present, with a long tail due to some very high counts. So we don't want to use a poisson distribution GAM model, instead we'll use a GAM model with a negtive binomial distribution based model which can handle overdispersion.
# 3. We tested this model using multiple degree's of freedom (4 - 12), this is how many basis functions it can use (wiggles). Found 7 to have the lowest AIC indicating the best fit.
# 4. This fitted model gave an effective degree's of freedom of 5.94 (meaning it used 5.94 of the available 7 df's), and a p value of 0.00094.
# 5. In conclusion: There is clear evidence that bomb fishing activity varies non-randomly over time. The plot shows a significant increase in August–September 2023 and a significant dip in October–December 2023.
# However, the model still only explained a modest amount of variation (pseudo R² = 0.08), suggesting high day-to-day stochasticity in activity. Additionally, we note the model provides projections (guesses) for the periods with missing data but we do not consider these of use for our purposes here.

# %%
# Cell 1: prepare daily counts for south recorder
import pandas as pd
from datetime import datetime, timedelta

# (re‑use your existing helper)
df_south = load_data_by_recorder(CSV_FOLDER, "south")

# aggregate
bombs_per_day, recordings_per_day = aggregate_daily_counts(df_south)

# put into one DataFrame
daily = pd.DataFrame({
    "date": bombs_per_day.index,
    "bombs": bombs_per_day.values,
    "recs" : recordings_per_day.values
})
daily["date"] = pd.to_datetime(daily["date"])
daily.set_index("date", inplace=True)

daily.head()
# Out:
#             bombs  recs
# date
# 2023-05-09     15    83
# 2023-05-10      2    36
# 2023-05-11     18    61
# 2023-05-12      3    34
# 2023-05-13     20    66

# %% [markdown]
# Check mean vs variance to choose ... ?

# %%
# Cell 2: adjusted dispersion check (recording‑days only, duty‑cycle corrected)

# Restrict to days when we actually recorded
recording_days = daily.loc[daily["recs"] > 0, "bombs"]

# Double counts to correct for 50% duty cycle
adjusted_counts = recording_days * 2

# Compute stats
mean_adj = adjusted_counts.mean()
var_adj  = adjusted_counts.var(ddof=1)
disp_adj = var_adj / mean_adj if mean_adj else float("nan")

print(f"Adjusted mean bombs per recording‑day = {mean_adj:.2f}")
print(f"Adjusted variance = {var_adj:.2f}")
print(f"Adjusted dispersion (Var/Mean) = {disp_adj:.2f}")

# We see variance is much bigger than mean, so dispersion is high.
# Out:
# Adjusted mean bombs per recording‑day = 26.72
# Adjusted variance = 319.96
# Adjusted dispersion (Var/Mean) = 11.98

# %% [markdown]
# Run model with multiple degree's of freedom to find the best fit using AIC

# %%
# Cell 3: explore different spline degrees of freedom for NB‑GAM

from statsmodels.gam.api import GLMGam, BSplines
import statsmodels.api as sm
import numpy as np

# Prepare data: only days with recordings, duty-cycle corrected
rec_days = daily.loc[daily["recs"] > 0].copy()
rec_days["adj_bombs"]   = rec_days["bombs"] * 2
rec_days["day_ordinal"] = (rec_days.index - rec_days.index.min()).days

# Response and intercept
y = rec_days["adj_bombs"].values
intercept = np.ones((len(y), 1))

# Test different numbers of spline basis functions to find lowest AIC (k = 7 for  bombs over time)
for k in [4, 5, 6, 7, 8, 9, 10, 11, 12]:
    # Build a cubic B-spline basis with k degrees of freedom
    bs = BSplines(rec_days[["day_ordinal"]], df=[k], degree=[3])
    model = GLMGam(
        endog=y,
        exog=intercept,
        smoother=bs,
        family=sm.families.NegativeBinomial()
    ).fit(disp=False)
    deviance_ratio = model.deviance / model.df_resid
    pearson_ratio = model.pearson_chi2 / model.df_resid
    print(f"k={k:2d} | Deviance/df = {deviance_ratio:.2f} | Pearson χ²/df = {pearson_ratio:.2f} | AIC = {model.aic:.1f}")
# Out:
# k= 4 | Deviance/df = 0.68 | Pearson χ²/df = 0.43 | AIC = 2302.9
# k= 5 | Deviance/df = 0.65 | Pearson χ²/df = 0.41 | AIC = 2297.1
# k= 6 | Deviance/df = 0.67 | Pearson χ²/df = 0.42 | AIC = 2302.5
# k= 7 | Deviance/df = 0.62 | Pearson χ²/df = 0.37 | AIC = 2289.7
# k= 8 | Deviance/df = 0.62 | Pearson χ²/df = 0.38 | AIC = 2293.0
# k= 9 | Deviance/df = 0.61 | Pearson χ²/df = 0.37 | AIC = 2290.4
# k=10 | Deviance/df = 0.61 | Pearson χ²/df = 0.37 | AIC = 2291.5
# k=11 | Deviance/df = 0.61 | Pearson χ²/df = 0.37 | AIC = 2293.1
# k=12 | Deviance/df = 0.61 | Pearson χ²/df = 0.37 | AIC = 2295.1
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "

# %% [markdown]
# Now run the model and plot it using the best fitting df from above
#
# From this we get effective degree's of freedom (edf) (Df Model) = 5.94. Flexible enough to pick up non‑linear trends but not so flexible as to chase every bump. The LRT score which shows there is a significant trend, with the statistical power and p value.

# %%
# Cell 4: fit final NB‑GAM (k=7), perform LRT, and plot smooth + 95% CI + grand mean

from statsmodels.gam.api import GLMGam, BSplines
import statsmodels.api as sm
from scipy.stats import chi2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# --- Prepare the data (same as before) ---
rec_days = daily.loc[daily["recs"] > 0].copy() # We drop days with no recordings here. Important for model.
rec_days["adj_bombs"]   = rec_days["bombs"] * 2
rec_days["day_ordinal"] = (rec_days.index - rec_days.index.min()).days

y = rec_days["adj_bombs"].values
intercept = np.ones((len(y), 1))

# --- Fit the GAM with df=7 splines ---
bs = BSplines(rec_days[["day_ordinal"]], df=[7], degree=[3])
gam7 = GLMGam(
    endog=y,
    exog=intercept,
    smoother=bs,
    family=sm.families.NegativeBinomial()
).fit()

# Extract effective degrees of freedom for the smooth
edf_smooth = gam7.df_model  

# --- Fit intercept-only NB‑GLM for LRT ---
X0 = sm.add_constant(np.zeros(len(y)))  # intercept-only design
glm0 = sm.GLM(y, X0, family=sm.families.NegativeBinomial()).fit(disp=False)

# Compute likelihood-ratio test statistic
LL0 = glm0.llf
LL1 = gam7.llf
chi2_stat = 2 * (LL1 - LL0)
p_value = 1 - chi2.cdf(chi2_stat, edf_smooth)

print(f"Smooth EDF = {edf_smooth:.2f}")
print(f"LRT chi2 = {chi2_stat:.2f}, df = {edf_smooth:.2f}, p = {p_value:.5f}")

# --- Create a fine grid for prediction ---
day_max = rec_days["day_ordinal"].max()
grid = np.arange(0, day_max + 1)[:, None]
exog_pred = np.ones((len(grid), 1))

pred = gam7.get_prediction(exog=exog_pred, exog_smooth=grid)
pred_df = pred.summary_frame(alpha=0.05)

# Turn back into dates
dates = rec_days.index.min() + pd.to_timedelta(grid.flatten(), "D")
pred_df["date"] = dates

# Grand mean line
grand_mean = y.mean()

# --- Plotting ---
fig, ax = plt.subplots(figsize=(12, 5))

ax.scatter(rec_days.index, y, alpha=0.3, label="Adjusted daily bombs")
ax.plot(pred_df["date"], pred_df["mean"], color="firebrick", lw=2, label="GAM fit (k=7)")
ax.fill_between(
    pred_df["date"],
    pred_df["mean_ci_lower"],
    pred_df["mean_ci_upper"],
    color="firebrick",
    alpha=0.2,
    label="95% CI"
)
ax.axhline(grand_mean, linestyle="--", color="gray", label=f"Grand mean = {grand_mean:.1f}")

ax.set_xlabel("Date", fontweight="bold")
ax.set_ylabel("Bombs per day (full‑day equivalent)", fontweight="bold")
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
fig.autofmt_xdate(rotation=45)
ax.legend(loc="upper right")
plt.tight_layout()
plt.show()
# Out:
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Smooth EDF = 5.94
# LRT chi2 = 22.49, df = 5.94, p = 0.00094

# %% [markdown]
# Check residuals
#
# We make two plots and see:
# 1. No obvious trend in residuals, the GAM is doing a consistant job overtime at fitting the data.
# 2. We also checked for temporal autocorrelation using ACF (Autocorrelation Function). The ACF mostly inside the confidence band, showing there’s only a very weak serial autocorrelation. (note the spike at 0 is normal apparently, as it always hits 1.0 and autocorrelates with itself)

# %%
# —— Residual diagnostics for NB‑GAM —— 
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# 1) Extract Pearson and deviance residuals
pearson_resid = gam7.resid_pearson
deviance_resid = gam7.resid_deviance

# 2) Make a time index
dates = rec_days.index

# 3) Residual vs time
fig, axs = plt.subplots(2, 1, figsize=(10, 6), sharex=True)
axs[0].scatter(dates, pearson_resid, alpha=0.5)
axs[0].axhline(0, color='gray', lw=1)
axs[0].set_title('Pearson residuals over time')
axs[0].set_ylabel('Pearson residual')

axs[1].scatter(dates, deviance_resid, alpha=0.5, color='C1')
axs[1].axhline(0, color='gray', lw=1)
axs[1].set_title('Deviance residuals over time')
axs[1].set_ylabel('Deviance residual')
plt.xlabel('Date')
fig.autofmt_xdate(rotation=30)
plt.tight_layout()
plt.show()

# 4) ACF of Pearson residuals
fig = plt.figure(figsize=(8, 3))
plot_acf(pearson_resid, lags=100, title='ACF of Pearson residuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# Nicer plot that merges the two

# %%
# Combined orange bars + GAM overlay with revised legend
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import timedelta
import statsmodels.api as sm
from statsmodels.gam.api import GLMGam, BSplines

# 1) Bar data
df = load_data_by_recorder(CSV_FOLDER, "south")
bombs_count, recordings_count = aggregate_daily_counts(df)
gaps = find_gap_spans(recordings_count)
colour = plt.rcParams["axes.prop_cycle"].by_key()["color"][1]

# 2) Prepare GAM data
rec_days = daily.loc[daily["recs"] > 0].copy()
rec_days["adj_bombs"]   = rec_days["bombs"] * 2
rec_days["day_ordinal"] = (rec_days.index - rec_days.index.min()).days
y = rec_days["adj_bombs"].values
intercept = np.ones((len(y), 1))

# 3) Fit NB‑GAM (k=7)
bs = BSplines(rec_days[["day_ordinal"]], df=[7], degree=[3])
gam7 = GLMGam(endog=y, exog=intercept, smoother=bs, 
              family=sm.families.NegativeBinomial()).fit(disp=False)

# 4) Predict on daily grid
grid = np.arange(0, rec_days["day_ordinal"].max()+1)[:, None]
pred = gam7.get_prediction(exog=np.ones((len(grid),1)),
                            exog_smooth=grid).summary_frame(alpha=0.05)
pred["date"] = rec_days.index.min() + pd.to_timedelta(grid.flatten(), "D")

# 5) Grand mean
grand_mean = y.mean()

# 6) Plot
fig, ax = plt.subplots(figsize=(9, 4.2))
bar_width, half_width = 1.0, 0.5

# a) Bars
ax.bar(bombs_count.index, bombs_count.values*2,
       width=bar_width, color=colour, alpha=0.3,
       label="Projected count (100% duty cycle)", zorder=1)
ax.bar(bombs_count.index, bombs_count.values,
       width=bar_width, color=colour,
       label="Verified count (50% duty cycle)", zorder=2)

# b) CI ribbon (no legend)
ax.fill_between(pred["date"], pred["mean_ci_lower"], pred["mean_ci_upper"],
                color="firebrick", alpha=0.2, zorder=3, label="_nolegend_")

# c) Spline line
ax.plot(pred["date"], pred["mean"],
        color="firebrick", lw=2, label="GAM smoother", zorder=3)

# d) Mean daily rate
ax.axhline(grand_mean, linestyle="--", color="gray",
           label="Mean", zorder=3)

# e) Grey gaps on top
for start, end in gaps:
    ax.axvspan(start+timedelta(days=half_width),
               end+timedelta(days=1-half_width),
               color="grey", alpha=0.3, zorder=4)

# f) Styling
ax.set_ylabel("Blasts per day", fontweight="bold")
ax.set_xlabel("Date", fontweight="bold")
ax.margins(x=0)
ax.set_ylim(bottom=0)
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
fig.autofmt_xdate(rotation=45)

# g) Custom legend: two columns
handles, labels = ax.get_legend_handles_labels()
order = [
    "Projected count (100% duty cycle)",
    "Verified count (50% duty cycle)",
    "GAM smoother",
    "Mean"
]
ordered_handles = [handles[labels.index(l)] for l in order]

ax.legend(
    ordered_handles,
    order,
    ncol=2,
    loc="upper center",
    bbox_to_anchor=(0.45, -0.35),
    frameon=False,
    columnspacing=4
)

plt.tight_layout()
save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", f"barplot_GAM.png")
plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()
# Out:
# /home/bwilliams/anaconda3/envs/scratch_conda_env/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "

# %% [markdown]
# Capation: Count of bomb fishing incidents over time. Each bar represents one calendar day. Tickmarks represent the start of each month. The verified count represents detections validated by human reviewers using the 50% ‘one-minute on one-minute off’ duty cycle employed during this study. The projected count represents the estimated rate of verified detections if the recorders had been deployed using a 100% on duty cycle, calculated by doubling the verified count of each day. The GAM smoother represents the fitted generalised additive model (GAM), with 95% confidence intervals. The mean daily rate represents the mean projected count.

# %%
# Cell: Mean adjusted bomb count for Oct–Dec 2023 (recording days only), fixed without SettingWithCopyWarning

# 1) Filter to recording days
recorded = daily.loc[daily["recs"] > 0].copy()

# 2) Restrict to Oct–Dec 2023
mask = (recorded.index >= "2023-10-01") & (recorded.index <= "2023-12-31")
oct_dec = recorded.loc[mask].copy()

# 3) Duty‑cycle correction using .loc
oct_dec.loc[:, "adj_bombs"] = oct_dec["bombs"]

# 4) Compute mean and count of days
mean_oct_dec = oct_dec["adj_bombs"].mean()
n_days       = len(oct_dec)

print(f"Verified bombs/day (Oct–Dec 2023, {n_days} recording days): {mean_oct_dec:.2f}")
# Out:
# Verified bombs/day (Oct–Dec 2023, 67 recording days): 8.28

# %% [markdown]
# ### Rose plot

# %%
# Rose plot: South Recorder bomb detections by hour,
#   with noon at the top, 2‐hour ticks, and day/night colouring.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from math import pi

# Load & filter for true bomb hits
df = load_data_by_recorder(CSV_FOLDER, "south")
hits = df[df["bomb_detected"]].copy()
hits["hour"] = hits["datetime"].dt.hour

# Count detections by hour (0–23)
hourly_counts = hits.groupby("hour").size().reindex(range(24), fill_value=0)
radii = hourly_counts.values
max_r = radii.max()

# sample 24 colours
colours = plt.rcParams["axes.prop_cycle"].by_key()["color"]
bar_colour = colours[1]   

# Compute angles for each hour
N = 24
angles = (np.arange(24) + 0.5) * (2*pi/24)
width = 2*pi / N

# Plot
fig, ax = plt.subplots(figsize=(4.5, 4.5), subplot_kw={"projection": "polar"})

# Bars
bars = ax.bar(
    angles,
    radii,
    width=width,
    bottom=0,
    color=bar_colour,   
    edgecolor="white",
    linewidth=0.8,
    alpha=0.9,
)

# Aesthetics
ax.set_theta_zero_location("S")   # 0h (midnight) at bottom → 12h (noon) at top
ax.set_theta_direction(-1)        # clockwise increases

# tick every 2 hours
hours = np.arange(0, 24, 2)
ticks = hours * 2*pi/24
ax.set_xticks(ticks)
ax.set_xticklabels([f"{h:02d}:00" for h in hours], fontsize=9, fontweight="bold")

# lighten grid, remove spine
ax.grid(color="grey", linestyle="--", linewidth=0.5, alpha=0.6)
ax.spines["polar"].set_visible(False)

### Radial ticks
#radials = np.linspace(0, max_r, 5)
#ax.set_yticks(radials)
#ax.set_yticklabels([f"{int(r)}" for r in radials], fontsize=10)
### No radial ticks
# radials = np.linspace(0, max_r, 5)
# ax.set_yticks(radials)
# ax.set_yticklabels([])  
### Custom radial ticks 
radial_values = [50, 100, 150, 200, 250, 300]
ax.set_yticks(radial_values)

# Only label every other one: show 100, 200, 300
radial_labels = [str(r) if r % 100 == 0 else "" for r in radial_values]
ax.set_yticklabels(radial_labels, fontsize=9)

plt.tight_layout()
save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", f"roseplot.png")
plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()

# %% [markdown]
# Makassar sits just south of the equator, so daylight hardly budges over the year – there is only about a 36-minute swing from shortest to longest day. At the June solstice (around 21 June) you’ll see roughly 11 h 49 min of light, and at the December solstice (around 21 December) about 12 h 25 min – that’s it, just half an hour or so difference
# Time and Date
# Time and Date
# .
#
# In day-to-day life the Sun basically pops up at about 6 am and clocks off at about 6 pm. For instance, on 30 May 2025 it rose at 06:04 am and set at 05:55 pm local time
# Time and Date
# . Through the year you’ll only ever see sunrises shift by a few minutes (you won’t catch it before about 05:50 am or after about 06:15 am) and sunsets land between roughly 17:45 and 18:15.

# %% [markdown]
# #### Plot and test trends in weekdays

# %%
from matplotlib.colors import LinearSegmentedColormap

# Create a pivot table: rows are weekdays (0–6), columns are hours (0–23), values are counts
hits["weekday"] = hits["datetime"].dt.dayofweek
weekday_hour_counts = (
    hits.groupby(["weekday", "hour"])
    .size()
    .unstack(fill_value=0)
    .reindex(index=range(7), fill_value=0)  # ensure all weekdays present
)

# Define two base colours
COLOUR1 = "navy"
COLOUR2 = "darkorange"

# Create a cyclic colormap that goes from COLOUR1 → COLOUR2 → COLOUR1
cyclic_cmap = LinearSegmentedColormap.from_list(
    "two_colour_cycle",
    [COLOUR1, COLOUR2, COLOUR1],
)

# Sample 24 colours from that cyclic map (so 00:00 and 23:00 are both close to COLOUR1)
hour_colours = [cyclic_cmap(i / 23) for i in range(24)]

# Plot stacked bar chart with spines and a pared-down legend
fig, ax = plt.subplots(figsize=(8, 5))

x_positions = range(7)
weekday_names = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
bottom = np.zeros(7, dtype=int)

# Loop in reverse so hour 23 is plotted first (at the bottom), then 22, …, down to 0
for hour in reversed(range(24)):
    counts = weekday_hour_counts[hour].values
    # Only label every other hour as before
    label = f"{hour:02d}:00" if hour % 2 == 0 else "_nolegend_"
    ax.bar(
        x_positions,
        counts,
        bottom=bottom,
        color=hour_colours[hour],
        edgecolor="white",
        linewidth=0.5,
        label=label,
    )
    bottom += counts  # stack the next (lower-numbered) hour on top

# Remove top/right spines
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Aesthetics
ax.set_xticks(x_positions)
ax.set_xticklabels(weekday_names, fontsize=9)
ax.set_xlabel("Day of week", fontsize=12, fontweight="bold")
ax.set_ylabel("Blast count", fontsize=12, fontweight="bold")

# Legend
leg = ax.legend(
    title="Hour of Day",
    bbox_to_anchor=(1.02, 0.95),
    loc="upper left",
    fontsize=10,
    title_fontsize=12,
    ncol=1,
    framealpha=0.1,
    labelspacing=1.2,
)
# Plot legend  with bold title font
leg.get_title().set_fontweight("bold")

plt.tight_layout()
plt.tight_layout()
save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", "weekdays.png")
plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()

# %%
# Test for weekday effect using a Negative‑Binomial GLM

import numpy as np
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import NegativeBinomial
from scipy.stats import chi2

# 1) Prepare daily, duty‑cycle‑corrected counts
df = load_data_by_recorder(CSV_FOLDER, "south")
bombs_count, recs_count = aggregate_daily_counts(df)
daily = pd.DataFrame({
    "bombs": bombs_count,
    "recs":  recs_count
})
daily = daily[daily["recs"] > 0].copy()
daily["adj_bombs"] = daily["bombs"] * 2
daily["weekday"]   = daily.index.dayofweek  # 0=Mon … 6=Sun

# 2) Build response and design matrix
y = daily["adj_bombs"].astype(float).values
X = pd.get_dummies(daily["weekday"], prefix="wd", drop_first=True)
X = sm.add_constant(X).astype(float)  # cast to float to avoid dtype issues

# 3) Fit full and null NB models
nb_full = NegativeBinomial(y, X).fit(disp=False)
X0     = sm.add_constant(pd.DataFrame({"intercept": np.ones_like(y)})).astype(float)
nb_null = NegativeBinomial(y, X0).fit(disp=False)

# 4) Likelihood‑ratio test
lr_stat  = 2 * (nb_full.llf - nb_null.llf)
df_diff  = int(nb_full.df_model - nb_null.df_model)
p_value  = chi2.sf(lr_stat, df_diff)

print(f"Weekday LRT χ² = {lr_stat:.2f}, df (num vars (weekdays) vs baseline) = {df_diff}, p = {p_value:.4f}\n")
print(nb_full.summary())
# Out:
# Weekday LRT χ² = 30.62, df (num vars (weekdays) vs baseline) = 6, p = 0.0000
#
#                      NegativeBinomial Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  267
# Model:               NegativeBinomial   Df Residuals:                      260
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 04 Aug 2025   Pseudo R-squ.:                 0.01355
# Time:                        12:15:14   Log-Likelihood:                -1114.7
# converged:                       True   LL-Null:                       -1130.0
# Covariance Type:            nonrobust   LLR p-value:                 3.000e-05
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.4555      0.118     29.194      0.000       3.224       3.688
# wd_1          -0.0729      0.164     -0.443      0.658      -0.395       0.249
# wd_2          -0.1481      0.167     -0.888      0.374      -0.475       0.179
# wd_3           0.0410      0.166      0.246      0.805      -0.285       0.367
# wd_4          -0.7805      0.168     -4.643      0.000      -1.110      -0.451
# wd_5          -0.0703      0.166     -0.422      0.673      -0.397       0.256
# wd_6          -0.3769      0.169     -2.236      0.025      -0.707      -0.047
# alpha          0.4868      0.046     10.552      0.000       0.396       0.577
# ==============================================================================

# %%
import seaborn as sns
sns.set_theme(style="white", rc={"axes.grid": False})

# %%
# Weekday effect plot

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# (Re‑run your NB‑GLM cell so nb_full is in memory)

# 1) Pull out estimates & SEs
coef   = nb_full.params
se     = nb_full.bse
ci95   = nb_full.conf_int()

# 2) Compute 75% CI critical value
z75 = norm.ppf(1 - 0.25/2)

# 3) Map model terms → weekdays (excluding Monday)
term_map = {
    "wd_1": "Tue",
    "wd_2": "Wed",
    "wd_3": "Thu",
    "wd_4": "Fri",
    "wd_5": "Sat",
    "wd_6": "Sun",
}

# 4) Build DataFrame for plotting
rows = []
for term, day in term_map.items():
    b = coef[term]
    lo95, hi95 = ci95.loc[term]
    lo75, hi75 = b - z75*se[term], b + z75*se[term]
    rows.append({
        "weekday": day,
        "est":      np.exp(b),
        "lo95":     np.exp(lo95),
        "hi95":     np.exp(hi95),
        "lo75":     np.exp(lo75),
        "hi75":     np.exp(hi75),
    })
dfp = pd.DataFrame(rows)

# 5) Plot
fig, ax = plt.subplots(figsize=(5.5, 4))

x = np.arange(len(dfp))

# 95% CI: thin line
for i in x:
    ax.plot([i, i],
            [dfp.lo95[i], dfp.hi95[i]],
            color="darkorange",
            linewidth=3)

# 75% CI: thick line
for i in x:
    ax.plot([i, i],
            [dfp.lo75[i], dfp.hi75[i]],
            color="darkorange",
            linewidth=5)

# Point estimate: solid dot, same colour, no edge
ax.plot(x, dfp.est,
        "o",
        color="darkorange",
        markersize=7,
        markeredgewidth=0)

# Monday baseline
ax.axhline(1.0,
           linestyle="--",
           color="black",
           linewidth=1)

# Styling to match thesis
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
for spine in ["left","bottom"]:
    ax.spines[spine].set_linewidth(1.5)
ax.tick_params(axis="both", which="both",
               direction="in", length=6, width=1.5)

ax.set_xticks(x)
ax.set_xticklabels(dfp.weekday, fontsize=10)
ax.set_xlabel("Day of week",   fontweight="bold", fontsize=12)
ax.set_ylabel("Relative blast rate by weekday", fontweight="bold", fontsize=12)

plt.tight_layout()
save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", "weekday_effects_plot.png")
plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()

# %%
import seaborn as sns
sns.reset_orig()

# %% [markdown]
# Check residuals, a bit  of a wonky tail on the Q-Q plot but lets consider this good enough

# %%
# Cell: Residual diagnostics for weekday NB‑GLM

import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import NegativeBinomialResults

def plot_nb_residuals(model: NegativeBinomialResults,
                      endog: np.ndarray,
                      exog: np.ndarray) -> None:
    """Plot diagnostic graphs for a NegativeBinomial model.

    Shows Pearson residuals versus fitted values and a QQ‑plot of residuals,
    and prints the overdispersion statistic.

    Args:
        model: Fitted NegativeBinomialResults object.
        endog: Observed response values used to fit the model.
        exog:  Predictor matrix used in the model.
    """
    # Compute fitted values and Pearson residuals
    fitted = model.predict(exog)
    pearson_resid = model.resid_pearson
    df_resid = model.df_resid

    # Overdispersion statistic: sum of squared Pearson residuals / df_resid
    dispersion = np.sum(pearson_resid**2) / df_resid
    print(f"Overdispersion (Pearson χ²/df) = {dispersion:.2f}")

    # Set up a two‑panel figure
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

    # 1) Residuals vs Fitted
    ax1.scatter(fitted, pearson_resid, alpha=0.6)
    ax1.axhline(0, color="gray", linestyle="--")
    ax1.set_xlabel("Fitted values")
    ax1.set_ylabel("Pearson residuals")
    ax1.set_title("Residuals vs Fitted")

    # 2) QQ‑plot of Pearson residuals
    sm.qqplot(pearson_resid, line="45", ax=ax2)
    ax2.set_title("QQ plot of Pearson residuals")

    plt.tight_layout()
    plt.show()

# Run diagnostics on the full NB model
plot_nb_residuals(nb_full, y, X)
# Out:
# Overdispersion (Pearson χ²/df) = 0.79

# %% [markdown]
# #### Back to dayly trends

# %%
from matplotlib.colors import LinearSegmentedColormap
from math import pi

# Load & filter for true bomb hits
df = load_data_by_recorder(CSV_FOLDER, "south")
hits = df[df["bomb_detected"]].copy()
hits["hour"] = hits["datetime"].dt.hour

# Count detections by hour (0–23)
hourly_counts = hits.groupby("hour").size().reindex(range(24), fill_value=0)
radii = hourly_counts.values
max_r = radii.max()

# Compute angles for each hour slice
N = 24
angles = (np.arange(N) + 0.5) * (2 * pi / N)
width = 2 * pi / N

# Create a two-colour cyclic map (navy → darkorange → navy)
COLOUR1 = "navy"
COLOUR2 = "darkorange"
cyclic_cmap = LinearSegmentedColormap.from_list(
    "two_colour_cycle",
    [COLOUR1, COLOUR2, COLOUR1],
)
# Sample 24 colours so 00:00 & 23:00 are both near navy
hour_colours = [cyclic_cmap(i / (N - 1)) for i in range(N)]

# Plot
fig, ax = plt.subplots(figsize=(4.5, 4.5), subplot_kw={"projection": "polar"})

# Bars: assign each hour its cyclic colour
bars = ax.bar(
    angles,
    radii,
    width=width,
    bottom=0,
    color=hour_colours,
    edgecolor="white",
    linewidth=0.8,
    alpha=0.9,
)

# Aesthetics: noon at top, clockwise progression
ax.set_theta_zero_location("S")
ax.set_theta_direction(-1)

# Tick every 2 hours
hours = np.arange(0, 24, 2)
ticks = hours * 2 * pi / 24
ax.set_xticks(ticks)
ax.set_xticklabels([f"{h:02d}:00" for h in hours], fontsize=9, fontweight="bold")

# Lighten grid, remove polar spine
ax.grid(color="grey", linestyle="--", linewidth=0.5, alpha=0.6)
ax.spines["polar"].set_visible(False)

# Radial ticks (only label 100, 200, 300)
radial_values = [50, 100, 150, 200, 250, 300]
ax.set_yticks(radial_values)
radial_labels = [str(r) if r % 100 == 0 else "" for r in radial_values]
ax.set_yticklabels(radial_labels, fontsize=9)
ax.set_rlabel_position(325) # set the angle the ticks come out at

# plot and save
plt.tight_layout()
save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", "roseplot.png")
plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()

# %% [markdown]
# Test if the diel trends are significant

# %%
# Rayleigh’s test for 24 h uniformity

# 1) Pull out every verified blast timestamp
df = load_data_by_recorder(CSV_FOLDER, "south")
hits = df[df["bomb_detected"]].copy()
times = hits["datetime"]

# 2) Convert each time to an angle [0, 2π) on the 24 h clock
#    (hour + minute/60 + second/3600) / 24 × 2π
angles = (times.dt.hour 
          + times.dt.minute/60 
          + times.dt.second/3600) 
angles = 2 * np.pi * angles / 24

# 3) Compute Rayleigh’s R statistic and z
n    = len(angles)
C    = np.sum(np.cos(angles))
S    = np.sum(np.sin(angles))
R    = np.sqrt(C**2 + S**2)
Rbar = R / n
z    = n * Rbar**2

# 4) Approximate p-value via exp(−z) (accurate for moderate‐large n)
p = np.exp(-z)

print(f"Rayleigh’s test for diel uniformity:")
print(f"  n = {n} blasts")
print(f"  R̄ = {Rbar:.3f}")
print(f"  z  = {z:.2f}")
print(f"  p ≈ {p:.3e}")
# Out:
# Rayleigh’s test for diel uniformity:
#   n = 3567 blasts
#   R̄ = 0.382
#   z  = 520.49
#   p ≈ 9.004e-227

# %% [markdown]
# ## Other stats to report in results

# %%
def total_detection_count(csv_folder: str) -> int:
    """Count the total number of rows across all CSV files in a folder.

    Args:
        csv_folder: Path to the folder containing CSV files.

    Returns:
        Total row count (int).
    """
    total = 0
    for fname in os.listdir(csv_folder):
        if fname.lower().endswith(".csv") and fname.lower().startswith("south"):
            fp = os.path.join(csv_folder, fname)
            df = pd.read_csv(fp)
            total += len(df)
    return total

# Run it and print
total_rows = total_detection_count(CSV_FOLDER)
print(f"Total detection count (all rows): {total_rows}")
# Out:
# Total detection count (all rows): 53545

# %%
# mean precision across the whole period:
# verified bomb count / detection count
3567 / total_rows
# Out:
# 0.06661686431973107

# %%
# Average daily precision per month
def average_daily_precision_per_month(csv_folder: str) -> None:
    """Compute and print average daily precision for each month in the study period.

    'Precision' here is defined as (bombs detected) / (recordings that day).

    Args:
        csv_folder: Path to the folder containing CSV files.
    """
    # Load both sites and concatenate
    df_south = load_data_by_recorder(csv_folder, "south")
    df_all = pd.concat([df_south], ignore_index=True)

    # Aggregate by day
    bombs_per_day, recs_per_day = aggregate_daily_counts(df_all)
    # daily precision series
    precision = bombs_per_day.divide(recs_per_day.replace(0, pd.NA))
    precision = precision.dropna()

    # Group by year-month and compute mean
    precision.index = precision.index.to_period("M")
    monthly_avg = precision.groupby(precision.index).mean()

    # Print in year-month order
    for period, avg in monthly_avg.items():
        year = period.year
        month = period.month
        print(f"{year}-{month:02d}  Avg precision: {avg:.3f}")

# Run it
print("this is daily avg precision per month (next cell is whole month):")
average_daily_precision_per_month(CSV_FOLDER)
# note it used the rolling avg so be sure to only take months below that are not greyed out in plots.
# Out:
# this is daily avg precision per month (next cell is whole month):
# 2023-05  Avg precision: 0.221
# 2023-06  Avg precision: 0.121
# 2023-07  Avg precision: 0.151
# 2023-08  Avg precision: 0.268
# 2023-09  Avg precision: 0.286
# 2023-10  Avg precision: 0.183
# 2023-11  Avg precision: 0.119
# 2023-12  Avg precision: 0.167
# 2024-02  Avg precision: 0.017
# 2024-03  Avg precision: 0.010
# 2024-06  Avg precision: 0.102
# 2024-07  Avg precision: 0.095
# 2024-08  Avg precision: 0.247
# 2024-09  Avg precision: 0.399

# %%
#Monthly weighted precision with recording-day counts and warnings
import pandas as pd

def monthly_weighted_precision_with_counts(csv_folder: str) -> None:
    """Compute and print each month's overall precision (total bombs ÷ total detections),
    along with the number of recording days. Warn if a month has fewer than 15 recording days.

    Args:
        csv_folder: Path to the folder containing CSV files.
    """
    # Load south‐only data (or include north if desired)
    df_south = load_data_by_recorder(csv_folder, "south")
    df_all = pd.concat([df_south], ignore_index=True)

    # Aggregate bombs and recordings per calendar day
    bombs_per_day, recs_per_day = aggregate_daily_counts(df_all)
    daily = pd.DataFrame({
        "bombs": bombs_per_day,
        "recs":  recs_per_day
    })

    # Restrict to days with at least one detection (i.e., recording days)
    recorded_days = daily[daily["recs"] > 0].copy()
    recorded_days["year_month"] = recorded_days.index.to_period("M")

    # For each month, sum bombs, sum detections, and count recording days
    monthly = (
        recorded_days
        .groupby("year_month")
        .agg(
            total_bombs=("bombs", "sum"),
            total_recs=("recs", "sum"),
            rec_days=("bombs", "count")
        )
        .assign(
            precision=lambda df: df["total_bombs"] / df["total_recs"]
        )
    )

    # Print header
    print("Year-Month │ Precision │ Recording Days │ Warning")
    print("---------- │ --------- │ -------------- │ -----------------")
    # Iterate in chronological order
    for period, row in monthly.iterrows():
        year = period.year
        month = period.month
        prec = row["precision"]
        days = int(row["rec_days"])
        warning = "⚠️ Less than 15 rec days" if days < 15 else ""
        print(f"{year}-{month:02d}    │   {prec:.3f}   │       {days:2d}        │ {warning}")

# Run it
monthly_weighted_precision_with_counts(CSV_FOLDER)
# Out:
# Year-Month │ Precision │ Recording Days │ Warning
# ---------- │ --------- │ -------------- │ -----------------
# 2023-05    │   0.109   │       15        │
# 2023-06    │   0.117   │       17        │
# 2023-07    │   0.087   │       19        │
# 2023-08    │   0.256   │       27        │
# 2023-09    │   0.282   │       27        │
# 2023-10    │   0.169   │       29        │
# 2023-11    │   0.095   │       30        │
# 2023-12    │   0.168   │        8        │ ⚠️ Less than 15 rec days
# 2024-02    │   0.018   │        8        │ ⚠️ Less than 15 rec days
# 2024-03    │   0.011   │        6        │ ⚠️ Less than 15 rec days
# 2024-06    │   0.047   │       23        │
# 2024-07    │   0.019   │       26        │
# 2024-08    │   0.243   │       30        │
# 2024-09    │   0.417   │        2        │ ⚠️ Less than 15 rec days

# %%
# Average count of detections per recording day in each calendar month
def avg_detections_per_rec_day_per_month(csv_folder: str) -> None:
    """Compute and print the average number of detections per recording day for each calendar month.

    If a month has fewer than 15 recorded days, a warning is printed next to it.

    Args:
        csv_folder: Path to the folder containing CSV files.
    """
    # Load both sites and concatenate
    df_south = load_data_by_recorder(csv_folder, "south")
    df_all = pd.concat([df_south], ignore_index=True)

    # Aggregate by day
    bombs_per_day, recs_per_day = aggregate_daily_counts(df_all)
    # Combine into a DataFrame
    daily = pd.DataFrame({
        "bombs": bombs_per_day,
        "recs": recs_per_day
    })
    # Only consider days with recordings
    recorded_days = daily[daily["recs"] > 0].copy()
    recorded_days["year_month"] = recorded_days.index.to_period("M")

    # For each year-month, sum bombs and count recording days
    grouped = recorded_days.groupby("year_month")
    for period, group in grouped:
        year = period.year
        month = period.month
        total_bombs = group["bombs"].sum()
        rec_days = len(group)
        avg_per_day = total_bombs / rec_days if rec_days > 0 else 0.0
        warning = "⚠️ Less than 15 rec days" if rec_days < 15 else ""
        print(f"{year}-{month:02d}  Avg bombs/rec day: {avg_per_day:.2f}  ({rec_days} rec days) {warning}")

# Run it
print(" Precision across full month (for recording days only)")
avg_detections_per_rec_day_per_month(CSV_FOLDER)
# not this should be doubled due to the duty cycle!
# Out:
#  Precision across full month (for recording days only)
# 2023-05  Avg bombs/rec day: 13.00  (15 rec days)
# 2023-06  Avg bombs/rec day: 12.53  (17 rec days)
# 2023-07  Avg bombs/rec day: 12.74  (19 rec days)
# 2023-08  Avg bombs/rec day: 21.11  (27 rec days)
# 2023-09  Avg bombs/rec day: 19.52  (27 rec days)
# 2023-10  Avg bombs/rec day: 10.24  (29 rec days)
# 2023-11  Avg bombs/rec day: 6.83  (30 rec days)
# 2023-12  Avg bombs/rec day: 6.62  (8 rec days) ⚠️ Less than 15 rec days
# 2024-02  Avg bombs/rec day: 16.25  (8 rec days) ⚠️ Less than 15 rec days
# 2024-03  Avg bombs/rec day: 11.67  (6 rec days) ⚠️ Less than 15 rec days
# 2024-06  Avg bombs/rec day: 14.00  (23 rec days)
# 2024-07  Avg bombs/rec day: 12.04  (26 rec days)
# 2024-08  Avg bombs/rec day: 13.50  (30 rec days)
# 2024-09  Avg bombs/rec day: 12.50  (2 rec days) ⚠️ Less than 15 rec days

# %%
# Highest single-day bomb count
def highest_daily_bomb_count(csv_folder: str) -> None:
    """Find and print the date with the highest number of bombs in a single day.

    Args:
        csv_folder: Path to the folder containing CSV files.
    """
    # Load south-only data (or combine north/south if you prefer)
    df_south = load_data_by_recorder(csv_folder, "south")

    # Get daily bomb counts
    bombs_per_day, _ = aggregate_daily_counts(df_south)

    # Identify the maximum
    max_bombs: int = int(bombs_per_day.max())
    max_day: date = bombs_per_day.idxmax().date()

    print(f"Highest bomb count in one day: {max_bombs} on {max_day}")

# Run it
highest_daily_bomb_count(CSV_FOLDER)
# Out:
# Highest bomb count in one day: 46 on 2023-09-25

# %%
# Percentage of bombs between 06:00 and 18:00
import pandas as pd

def percent_bombs_daytime(csv_folder: str) -> None:
    """Compute and print the percentage of bomb detections that occurred between 06:00 and 18:00.

    Args:
        csv_folder: Path to the folder containing CSV files.
    """
    # Load south (or both, depending on whether north matters; here we use both)
    df_south = load_data_by_recorder(csv_folder, "south")
    df_all = pd.concat([df_south], ignore_index=True)

    # Filter only bomb hits
    hits = df_all[df_all["bomb_detected"]].copy()
    hits["hour"] = hits["datetime"].dt.hour

    total_hits = len(hits)
    daytime_hits = hits.loc[hits["hour"].between(6, 17)].shape[0]
    if total_hits == 0:
        print("No bombs detected at all.")
        return

    pct = (daytime_hits / total_hits) * 100
    print(f"Bombs between 06:00–18:00: {daytime_hits} of {total_hits} ({pct:.1f}%)")

# Run it
percent_bombs_daytime(CSV_FOLDER)
# Out:
# Bombs between 06:00–18:00: 2649 of 3567 (74.3%)

# %%
# Cell: Average bombs per recording-day by weekday
import pandas as pd

def avg_bombs_per_rec_day_by_weekday(csv_folder: str) -> None:
    """Compute the average number of bombs per recording-day for each weekday (Mon=0 … Sun=6)."""

    # Load and concatenate both north/south
    df_south = load_data_by_recorder(csv_folder, "south")
    df_all = pd.concat([df_south], ignore_index=True)

    # Get bombs and recordings counts per calendar day
    bombs_per_day, recs_per_day = aggregate_daily_counts(df_all)

    # Build a DataFrame with only days that actually have recordings
    daily = pd.DataFrame({
        "date": bombs_per_day.index,
        "bombs": bombs_per_day.values,
        "recs": recs_per_day.values,
    })
    recorded = daily[daily["recs"] > 0].copy()

    # Extract weekday (0=Mon … 6=Sun) from the date
    recorded["weekday"] = recorded["date"].dt.dayofweek

    # Now average bombs over only those days with recordings, grouped by weekday
    weekday_avg_rec = recorded.groupby("weekday")["bombs"].mean()

    weekday_names = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
    for wd, avg in weekday_avg_rec.items():
        name = weekday_names[wd]
        print(f"{name}: {avg:.2f} bombs per recording-day on average")

# Run it
avg_bombs_per_rec_day_by_weekday(CSV_FOLDER)
# Out:
# Mon: 15.84 bombs per recording-day on average
# Tue: 14.72 bombs per recording-day on average
# Wed: 13.66 bombs per recording-day on average
# Thu: 16.50 bombs per recording-day on average
# Fri: 7.26 bombs per recording-day on average
# Sat: 14.76 bombs per recording-day on average
# Sun: 10.86 bombs per recording-day on average

# %% [markdown]
# ### Plot precision

# %%
# South-only daily classifier precision plot (masking grey periods)

# Parameters
recorder = "south"
bar_width = 1.0    # days
half_width = bar_width / 2  # inset for shading
smoothing_window = 3   # days for rolling mean

# Load data and add 'date'
df = load_data_by_recorder(CSV_FOLDER, recorder).copy()
df['date'] = df['datetime'].dt.date

# Get daily bomb counts and total detections
bombs_count, recordings_count = aggregate_daily_counts(df)

# Compute daily precision (true positives / hits), avoid divide-by-zero
precision = bombs_count / recordings_count.replace(0, np.nan)

# Smooth precision with rolling mean
smoothed = precision.rolling(
    window=smoothing_window,
    center=True,
    min_periods=1
).mean()

# Mask out days with no recordings so the line skips grey gaps
smoothed[recordings_count == 0] = np.nan

# Identify gaps for shading
gaps = find_gap_spans(recordings_count)

# Plot
fig, ax = plt.subplots(figsize=(9, 2.5))

# Shade no-recording gaps
for start, end in gaps:
    ax.axvspan(
        start + timedelta(days=half_width),
        end   + timedelta(days=1 - half_width),
        color="grey",
        alpha=0.3,
        zorder=0,
    )

# Plot smoothed precision line
ax.plot(
    smoothed.index,
    smoothed.values,
    color="blue",
    linewidth=1,
    label=f"{smoothing_window}-day rolling precision",
    zorder=1,
)

# Formatting
ax.set_ylim(0, 1)
ax.margins(x=0)
ax.set_title("South Daily Classifier Precision")
ax.set_ylabel("Precision", fontweight="bold")
#ax.legend(loc="upper right")
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
fig.autofmt_xdate(rotation=45)
plt.xlabel("Date", fontweight="bold")
plt.tight_layout()
save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", f"precisionplot.png")
plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()

# %% [markdown]
# ### Stats on precision

# %%
# Cell 1: prepare daily precision time series for south recorder

# 1) load south data
df_south = load_data_by_recorder(CSV_FOLDER, "south")

# 2) aggregate counts per day
#    - true positives = bombs_count
#    - total model hits = hits_count
bombs_count, hits_count = aggregate_daily_counts(df_south)

# 3) build a DataFrame and compute precision
precision_df = pd.DataFrame({
    "date":           bombs_count.index,
    "true_positives": bombs_count.values,
    "total_hits":     hits_count.values,
})
# avoid division by zero
precision_df["precision"] = (
    precision_df["true_positives"] 
    / precision_df["total_hits"].replace(0, pd.NA)
)

# 4) filter out days with zero hits
precision_df.set_index("date", inplace=True)
precision_df = precision_df.loc[precision_df["total_hits"] > 0]

# 5) inspect
precision_df.head()
# Out:
#             true_positives  total_hits precision
# date
# 2023-05-09              15          83  0.180723
# 2023-05-10               2          36  0.055556
# 2023-05-11              18          61  0.295082
# 2023-05-12               3          34  0.088235
# 2023-05-13              20          66   0.30303

# %%
# Cell 2: inspect daily precision distribution and its relationship with sample size

# 1) Summary statistics
print("Precision summary:")
print( precision_df["precision"].describe() )
print(f"\nDays with precision = 0: {(precision_df['precision'] == 0).sum()}")
print(f"Days with precision = 1: {(precision_df['precision'] == 1).sum()}")

# 3) Scatter of precision vs. total_hits to check for any dependence on sample size
fig, ax = plt.subplots(figsize=(8, 4))
ax.scatter(precision_df["total_hits"], precision_df["precision"], alpha=0.6)
ax.set_xlabel("Total model hits per day")
ax.set_ylabel("Precision")
ax.set_title("Daily precision vs. number of hits")
plt.tight_layout()
plt.show()
# Out:
# Precision summary:
# count     267.0
# unique    226.0
# top         0.0
# freq        8.0
# Name: precision, dtype: float64
#
# Days with precision = 0: 8
# Days with precision = 1: 0

# %% [markdown]
# The key thing this plot above is telling us is that daily‐precision is highly heteroskedastic: days with very few model hits can show almost any precision (0→0.6), whereas on high‑hit days precision collapses toward zero.
#
# So we run precision as a binomial response using a GAM with a logit link, and weight each day by its total_hit.
#
# First we find the optimal degrees of freedom by fitting multiple models and picking the lowest aic

# %%
# Cell 3: choose optimal spline df for Beta‐GAM by AIC
import numpy as np
import pandas as pd
from patsy import dmatrix, bs as patsy_bs
import statsmodels.api as sm
from statsmodels.othermod.betareg import BetaModel

# 1) Prepare & “squeeze” precision exactly as in your final cell
p = precision_df.copy().loc[precision_df['total_hits'] > 0].copy()
p['precision_raw'] = p['true_positives'] / p['total_hits']
n = len(p)
p['precision'] = ((p['precision_raw'] * (n - 1) + 0.5) / n)
p['day_ordinal'] = (p.index - p.index.min()).days

# 2) Loop over candidate spline dfs and record AIC
records = []
for k in range(4, 13):
    # build a Patsy basis with k df
    Xk = dmatrix(
        f"patsy_bs(day_ordinal, df={k}, degree=3, include_intercept=False)",
        data=p,
        return_type="dataframe"
    )
    Xk = sm.add_constant(Xk)  # add intercept

    # fit the Beta regression
    mod = BetaModel(endog=p['precision'], exog=Xk)
    res = mod.fit(disp=False)
    records.append((k, res.aic))

# 3) Summarise and pick best
aic_df = pd.DataFrame(records, columns=['spline_df','AIC']).set_index('spline_df')
print(aic_df.sort_values('AIC'))
best_k = aic_df['AIC'].idxmin()
print(f"\n→ Lowest AIC at spline_df = {best_k} (AIC = {aic_df.loc[best_k,'AIC']:.1f})")
# Out:
#                   AIC
# spline_df
# 9         -498.969813
# 6         -496.813406
# 10        -495.190482
# 12        -495.147543
# 11        -494.869998
# 8         -492.742899
# 7         -492.414230
# 5         -483.499184
# 4         -479.049617
#
# → Lowest AIC at spline_df = 9 (AIC = -499.0)

# %%
# Cell 4: Beta‑family GAM on daily precision (0–1) with LRT + plot

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from patsy import dmatrix, bs
import statsmodels.api as sm
from statsmodels.othermod.betareg import BetaModel
from scipy.stats import chi2

# 1) Prepare & “squeeze” precision into (0,1)
p = precision_df.copy().loc[precision_df['total_hits'] > 0].copy()
p['precision_raw'] = p['true_positives'] / p['total_hits']
n = len(p)
# Smithson & Verkuilen (2006) “squeeze”
p['precision'] = ((p['precision_raw'] * (n - 1) + 0.5) / n)
p['day_ordinal'] = (p.index - p.index.min()).days

# 2) Build spline basis via Patsy (7 df cubic B‑splines)
X_spline = dmatrix(
    "bs(day_ordinal, df=9, degree=3, include_intercept=False)",
    data=p,
    return_type="dataframe"
)
X_spline = sm.add_constant(X_spline)

# 3) Fit full BetaModel
mod_full = BetaModel(endog=p['precision'], exog=X_spline)
res_full = mod_full.fit(disp=False)

# 4) Fit intercept‑only (null) BetaModel
X_null = sm.add_constant(np.ones(len(p)))
mod_null = BetaModel(endog=p['precision'], exog=X_null)
res_null = mod_null.fit(disp=False)

# 5) Likelihood‐ratio test
LL_full = res_full.llf
LL_null = res_null.llf
df_diff = res_full.df_model - res_null.df_model
chi2_stat = 2 * (LL_full - LL_null)
p_value = 1 - chi2.cdf(chi2_stat, df_diff)
print(f"LRT χ² = {chi2_stat:.2f}, df = {df_diff:.0f}, p = {p_value:.4f}")

# 6) Extract fitted values
p['fitted'] = res_full.fittedvalues

# 7) Plot
fig, ax = plt.subplots(figsize=(12, 5))
ax.scatter(p.index, p['precision_raw'],
           color='gray', alpha=0.4, label='Daily precision')
ax.plot(p.index, p['fitted'],
        color='firebrick', lw=2, label='Spline fit')
ax.axhline(p['precision_raw'].mean(),
           linestyle='--', color='gray',
           label=f"Mean precision = {p['precision_raw'].mean():.2f}")

ax.set_xlabel('Date', fontweight='bold')
ax.set_ylabel('Precision', fontweight='bold')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
fig.autofmt_xdate(rotation=45)
ax.legend(loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# LRT χ² = 107.65, df = 9, p = 0.0000

# %% [markdown]
# Plot it but better

# %%
# Cell6 
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy.special import expit
from datetime import timedelta

# 1) Extract only the mean‐model coefficients & cov for the first k columns:
k = X_spline.shape[1]
beta_mean = res_full.params.values[:k]
covb_mean = res_full.cov_params().values[:k, :k]

# 2) Compute eta and its delta‐method SE on the original days
eta    = X_spline.values @ beta_mean
var_eta= np.sum((X_spline.values @ covb_mean) * X_spline.values, axis=1)
se_eta = np.sqrt(var_eta)

eta_lo, eta_hi = eta - 1.96*se_eta, eta + 1.96*se_eta
mu, mu_lo, mu_hi = expit(eta), expit(eta_lo), expit(eta_hi)

# 3) Recompute your grey‐gap spans
_, recs = aggregate_daily_counts(load_data_by_recorder(CSV_FOLDER, "south"))
gaps = find_gap_spans(recs)
half = 0.5

# 4) Plot
fig, ax = plt.subplots(figsize=(9, 2.5))

# (a) grey shading
for start, end in gaps:
    ax.axvspan(
        start + timedelta(days=half),
        end   + timedelta(days=1-half),
        color='grey', alpha=0.3, zorder=0
    )

# (b) blue bars of raw daily precision
ax.bar(
    p.index, p['precision_raw'],
    width=1.0, color='steelblue', alpha=1,
    label='Daily precision', zorder=1
)

# (c) CI ribbon in firebrick
ax.fill_between(
    p.index, mu_lo, mu_hi,
    color='firebrick', alpha=0.2, zorder=2,
    label='_nolegend_'
)

# (d) spline fit line
ax.plot(
    p.index, res_full.fittedvalues,
    color='firebrick', lw=2, label='GAM smoother', zorder=3
)

# (e) horizontal mean
mean_p = p['precision_raw'].mean()
ax.axhline(
    mean_p, linestyle='--', color='gray',
    label=f"Mean", zorder=4
)

# Formatting
ax.set_ylim(0, 0.7)
ax.set_xlim(p.index.min(), p.index.max())
ax.set_xlabel('Date', fontweight='bold')
ax.set_ylabel('Precision', fontweight='bold')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
fig.autofmt_xdate(rotation=45)

# We take the legend from the bomb count model, uncomment below to use this one
# # Legend underneath
# ax.legend(
#     ncol=3, frameon=False,
#     # gap between legend columns
#     columnspacing=3,
#     loc='upper center', bbox_to_anchor=(0.5, -0.52)
# )

plt.tight_layout()
save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", f"precisionplot_GAM.png")
plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()

# %% [markdown]
# Note the mean precision here looks high (0.17) compared to the 0.067 we got earlier. Remember, this is because here days with very few detections count just as much as days with loads and we are averaging by day here. But usually those with loads of detections have loads because the precision sucked (i.e some new fish chorus triggered false positives), meaning they skew the overall precision to be lower (to 0.067).
#
# Now check the residuals and temporal autocorrelation as above for the first GAM:
# 1. We see residuals looks good, constant variance of models fit overtime.
# 2. Very minimal signs of temporal autocorrelation.

# %%
# —— Residual diagnostics for Precision Beta‑GAM —— 
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# 1) raw residuals
p["residual"] = p["precision_raw"] - p["fitted"]

# 2) Residual vs time
fig, ax = plt.subplots(1, 1, figsize=(10, 3))
ax.scatter(p.index, p["residual"], alpha=0.6)
ax.axhline(0, color="gray", lw=1)
ax.set_title("Precision raw residuals over time")
ax.set_ylabel("Precision_raw − Fitted")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# 3) ACF of raw residuals
fig = plt.figure(figsize=(8, 3))
plot_acf(p["residual"], lags=100, title="ACF of Precision residuals")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Combined South bombardment & precision with dual y-axes
# Didn't like this so ditched it.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import timedelta

# Parameters
recorder         = "south"
bar_width        = 1.0                      # width of each bar in days
half_width       = bar_width / 2            # inset for gap shading
smoothing_window = 7                        # days for rolling mean
colours          = plt.rcParams["axes.prop_cycle"].by_key()["color"]
bar_colour       = colours[1]               # orange
line_colour      = "blue"                   # precision line

# 1) Load & prepare data
df = load_data_by_recorder(CSV_FOLDER, recorder).copy()
df["date"] = df["datetime"].dt.date

# 2) Daily bomb counts (true positives) and recording hits (all entries)
daily_hits = df.groupby("date").size()                      # total flagged hits/day
daily_true = df[df["bomb_detected"]].groupby("date").size() # validated bombs/day

# 3) Align to full date range
all_days = pd.date_range(daily_hits.index.min(), daily_hits.index.max(), freq="D").date
hits = daily_hits.reindex(all_days, fill_value=0)
true = daily_true.reindex(all_days, fill_value=0)
dates = pd.to_datetime(all_days)

# 4) Compute precision only on days with hits
precision = true / hits.replace(0, np.nan)

# 5) Smooth precision
smoothed = precision.rolling(window=smoothing_window, center=True, min_periods=1).mean()

# 6) Identify no‐recording gaps for shading
_, recordings_count = aggregate_daily_counts(df)
gaps = find_gap_spans(recordings_count)

# 7) Break the line over gaps: mask smoothed where no recordings
smoothed[recordings_count == 0] = np.nan

# 8) Create figure with two y-axes
fig, ax1 = plt.subplots(figsize=(12, 5))
ax2 = ax1.twinx()

# 9) Shade gaps on ax1 (covers background of both axes)
for start, end in gaps:
    ax1.axvspan(
        start + timedelta(days=half_width),
        end   + timedelta(days=1 - half_width),
        color="grey",
        alpha=0.3,
        zorder=0,
    )

# 10) Plot bomb counts on ax1
ax1.bar(
    dates,
    true.values * 2,        # double-height background
    width=bar_width,
    color=bar_colour,
    alpha=0.3,
    label="Double bombs count",
    zorder=1,
)
ax1.bar(
    dates,
    true.values,
    width=bar_width,
    color=bar_colour,
    label="Bombs count",
    zorder=2,
)

# 11) Plot precision line on ax2
ax2.plot(
    dates,
    smoothed.values,
    color=line_colour,
    linewidth=2,
    label=f"{smoothing_window}-day rolling precision",
    zorder=3,
)

# 12) Formatting
ax1.margins(x=0)             # no extra x-margins
ax1.set_ylabel("Bomb count per day")
ax2.set_ylabel("Precision")
ax2.set_ylim(0, 1)           # precision between 0 and 1
ax1.set_title("South Daily Bomb Detections & Classifier Precision")

# Legends: combine handles from both axes
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(handles1 + handles2, labels1 + labels2, loc="upper left")

# X-axis date formatting
ax1.xaxis.set_major_locator(mdates.MonthLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
fig.autofmt_xdate(rotation=45)
plt.xlabel("Date")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Print recording len and bomb count
# This is total time that ahs passed between the start of deployment and end. So later we cut in half to get the true recording time due to 1 in 2 min duty cycle.

# %%
def get_recording_periods(csv_folder: str, recorder_prefix: str) -> pd.DataFrame:
    """Compute start and end datetimes for each CSV (continuous recording period).

    Args:
        csv_folder: Path to CSV folder.
        recorder_prefix: 'north' or 'south'.

    Returns:
        DataFrame with columns ['file', 'start', 'end', 'duration'].
    """
    records = []
    for fname in os.listdir(csv_folder):
        if not fname.lower().startswith(recorder_prefix.lower()) or not fname.lower().endswith('.csv'):
            continue
        path = os.path.join(csv_folder, fname)
        tmp = pd.read_csv(path)
        # parse first and last datetime
        times = (
            tmp['File'].str.replace('.WAV', '', regex=False)
            .apply(lambda x: datetime.strptime(x, '%Y%m%d_%H%M%S'))
        )
        start, end = times.min(), times.max()
        duration = end - start
        records.append({'file': fname, 'start': start, 'end': end, 'duration': duration})
    return pd.DataFrame(records)


def print_summary(csv_folder: str) -> None:
    """Print bomb totals and bombs-per-recording-day rate for each site."""
    for site in ['north', 'south']:
        # Load data and periods
        df = load_data_by_recorder(csv_folder, site)
        periods = get_recording_periods(csv_folder, site)

        # Total bombs
        raw = int(df['bomb_detected'].sum())
        doubled = raw * 2

        # Overall span
        start = periods['start'].min().date()
        end   = periods['end'].max().date()
        days_total = (end - start).days + 1

        # Total audio duration adjusted for duty cycle
        total_dur = periods['duration'].sum() / 2  # a timedelta
        days_rec  = total_dur.total_seconds() / (3600 * 24)  # float days

        # Simple rate: bombs per recording-day
        bombs_per_rec_day = raw / days_rec if days_rec > 0 else float('nan')

        # Print summary
        print(f"{site.capitalize()} site:")
        print(f"  Period: {start} → {end} ({days_total} days inclusive)")
        print(f"  Bombs detected: {raw} (×2 → {doubled})")
        print(f"  Recording-days (adjusted): {days_rec:.2f}")
        print(f"  Bombs per recording-day: {bombs_per_rec_day:.2f}\n")


print_summary(CSV_FOLDER)
# Out:
# North site:
#   Period: 2023-05-10 → 2024-09-01 (481 days inclusive)
#   Bombs detected: 2296 (×2 → 4592)
#   Recording-days (adjusted): 169.54
#   Bombs per recording-day: 13.54
#
# South site:
#   Period: 2023-05-09 → 2024-09-02 (483 days inclusive)
#   Bombs detected: 3567 (×2 → 7134)
#   Recording-days (adjusted): 154.12
#   Bombs per recording-day: 23.14

# %% [markdown]
# # Plot example spectrograms

# %%
from typing import List, Dict
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from math import ceil

# Global constants for subplot dimensions and spacing
SPEC_WIDTH = 3      # width per subplot (in inches)
SPEC_HEIGHT = 2     # height per subplot (in inches)
SPEC_HGAP = 0.5     # horizontal gap between subplots
SPEC_VGAP = 0.2     # vertical gap between subplots

# Directory settings
AUDIO_DIR = os.path.join(BASE_DIR, "bomb_fishing/data/figures/plot_audio/final")
#OUTPUT_FILE = os.path.join(BASE_DIR, "bomb_fishing/example_bombs.png") # just save from here

# Spectrogram parameters
SR = 8000         # sampling rate
DURATION = 2.88     # seconds to load from each file
N_COLS = 3         # number of columns in the grid

def get_wav_files(folder_path: str) -> list[str]:
    """
    Return a sorted list of all .wav files in folder_path.
    """
    return sorted(
        [
            os.path.join(folder_path, f)
            for f in os.listdir(folder_path)
            if f.lower().endswith(".wav")
        ]
    )

def compute_log_mel_spectrogram(
    file_path: str, sr: int = SR, duration: float = DURATION
) -> np.ndarray:
    """
    Load up to `duration` seconds from file_path at sample rate `sr`,
    compute a Mel spectrogram, then convert to log scale (dB).
    """
    y, _ = librosa.load(file_path, sr=sr, duration=duration)
    if len(y) > sr * duration:
        y = y[: int(sr * duration)]
    mel_spec = librosa.feature.melspectrogram(
        y=y,
        sr=sr,
        n_fft=1024,
        win_length=512,
        hop_length=128,
        window="hann",
        pad_mode="constant",
        power=2.0,
        fmax=4000,
        n_mels=512,
    )
    return librosa.power_to_db(mel_spec, ref=np.max)

def plot_spectrogram_grid(
    spectrograms: list[np.ndarray],
    titles: list[str],
    ncols: int = N_COLS,
    sr: int = SR,
    duration: float = DURATION,
    output_file: str | None = None,
) -> None:
    """
    Plot a grid of Mel spectrograms (log scale) for each item in `spectrograms`.
    - `titles` should match the length of `spectrograms`.
    - Uses `ncols` columns; number of rows is auto-computed.
    - If `output_file` is not None, saves the figure there.
    """
    n_files = len(spectrograms)
    nrows = ceil(n_files / ncols)
    figsize = (ncols * 3, nrows * 2)
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize, constrained_layout=False)
    plt.subplots_adjust(wspace=0.5, hspace=0.4)

    # Flatten axes array or wrap single axis in list for consistency
    if n_files == 1:
        axes = [axes]  # single subplot
    else:
        axes = axes.flatten()

    for i, (spec, title) in enumerate(zip(spectrograms, titles)):
        ax = axes[i]
        librosa.display.specshow(
            spec,
            sr=sr,
            x_axis="time",
            y_axis="mel",
            fmax=8000,
            ax=ax,
            cmap="gray_r",  # reversed gray so hotter regions are darker
            x_coords=np.linspace(0, duration, spec.shape[1]),
        )
        #ax.set_title(title, fontsize=12, fontweight="bold")
        ax.set_xlabel("Time (s)", fontsize=10)
        ax.set_ylabel("Frequency (Hz)", fontsize=10)
        ax.tick_params(axis="x", labelsize=8, direction="out")
        ax.tick_params(axis="y", labelsize=8, direction="out")

    # Remove any extra subplots
    for j in range(n_files, len(axes)):
        fig.delaxes(axes[j])

    save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", f"bomb_examples.png")
    plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
    plt.show()

wav_files = get_wav_files(AUDIO_DIR)
spectrograms = [compute_log_mel_spectrogram(f) for f in wav_files]
titles = [os.path.basename(f) for f in wav_files]
plot_spectrogram_grid(spectrograms, titles)

# %% [markdown]
# ## Map
# Ripped right from my other PhD chapter so is a bit over engineered: https://github.com/BenUCL/MARRS_global_acoustic_study/blob/main/manuscript_docs/figures.ipynb

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import math
import matplotlib.ticker as mticker
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import matplotlib.font_manager as fm

import os
import math
from typing import Union, Tuple

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# Global variables (BASE_DIR is already set)
BUFFER = 500
COLOUR_MAPPING = {"B": 'black', "H": "#1b7837", "D": "#500072", "N": "#c2a5cf", "R": "#acd39e"}
DOT_EDGE_WIDTH = 1.5  # Outline width for dots


def add_north_arrow(ax, location: Union[str, Tuple[float, float]] = "upper left", zoom: float = 0.08) -> None:
  """Add a north arrow from an image file.

  Parameters:
    ax: The matplotlib axes.
    location: Either a tuple (in axes fraction) or a string keyword for position.
    zoom: Zoom factor for the arrow image.
  """
  # Map location string to axes fraction coordinates
  pos_dict = {
      "upper left": (0.1, 0.87),
      "upper right": (0.95, 0.9),
      "lower left": (0.05, 0.05),
      "lower right": (0.93, 0.12),
      "center": (0.5, 0.5)
  }
  loc = pos_dict.get(location.lower(), (0.05, 0.95)) if isinstance(location, str) else location
  img_path = os.path.join(BASE_DIR, "marrs_acoustics/data/figures/north_arrow_pixabay.png")
  img = mpimg.imread(img_path)
  imagebox = OffsetImage(img, zoom=zoom)
  ab = AnnotationBbox(imagebox, loc, xycoords="axes fraction", frameon=False)
  ax.add_artist(ab)

def add_scalebar(ax: plt.Axes, 
                 length: float, 
                 location: Union[str, Tuple[float, float]] = "lower left",
                 tick_count: int = 5, 
                 thickness: float = 2.5,
                 pos_override: dict = None) -> None:
  """Add a customised scale bar with tick marks.
  
  Parameters:
    ax: The matplotlib axes.
    length: The scale bar length in data units (e.g. metres).
    location: Either a tuple (in axes fraction) or a string keyword for position.
    tick_count: Number of tick marks (including endpoints).
    thickness: Line thickness for the bar and ticks.
    pos_override: Optional dictionary to override default position mapping.
  """
  pos_dict = {
      "upper left": (0.05, 0.95),
      "upper right": (-0.5, -0.5),
      "lower left": (-0.06, 0.08),
      "lower right": (0.95, 0.2),
      "center": (0.5, 0.5)
  }
  if pos_override:
      pos_dict.update(pos_override)
  loc_frac = pos_dict.get(location.lower(), (0.05, 0.05)) if isinstance(location, str) else location
  # Convert axes fraction to data coordinates
  start_disp = ax.transAxes.transform(loc_frac)
  start_data = ax.transData.inverted().transform(start_disp)
  x0, y0 = start_data[0], start_data[1]
  # Draw the horizontal scale bar
  ax.plot([x0, x0 + length], [y0, y0], color="black", linewidth=thickness, zorder=10)
  # Draw tick marks along the bar (ticks drawn downward)
  for i in range(tick_count):
      tick_x = x0 + i * (length / (tick_count - 1))
      tick_pixels = 10  # tick height in pixels
      tick_disp_start = ax.transData.transform((tick_x, y0))
      tick_disp_end = (tick_disp_start[0], tick_disp_start[1] - tick_pixels)
      tick_data_end = ax.transData.inverted().transform(tick_disp_end)
      tick_length = y0 - tick_data_end[1]
      ax.plot([tick_x, tick_x], [y0, y0 - tick_length], color="black", linewidth=thickness, zorder=10)
  # Place the label above the middle tick
  mid_x = x0 + length / 2
  ax.annotate(f"{length/1000:.1f} km", xy=(mid_x, y0), xytext=(0, 15),
              textcoords="offset points", ha="center", va="bottom",
              fontsize=20, color="black", zorder=10)


# Custom tick formatter: convert EPSG:3857 x (meters) to approximate longitude (degrees)
def make_x_formatter(decimals=2):
    fmt = f"{{:.{decimals}f}}"
    def x_formatter(x, pos):
        return fmt.format(x/6378137*180/math.pi)
    return x_formatter

def make_y_formatter(decimals=2):
    fmt = f"{{:.{decimals}f}}"
    def y_formatter(y, pos):
        lat = (math.pi/2 - 2*math.atan(math.exp(-y/6378137)))*180/math.pi
        return fmt.format(lat)
    return y_formatter

# %% [markdown]
# #### Add grey dots for localisation field test

# %%
import pandas as pd
from shapely.geometry import Point

# Define data
lat = -4.92992
lon = 119.31595

# Create geometry using shapely
geom = Point(13282190.798, -549474.605)

# Build DataFrame
df = pd.DataFrame({
  "Latitude": [lat],
  "Longitude": [lon],
  "geometry": [geom]
})

df
# Out:
#    Latitude  Longitude                          geometry
# 0  -4.92992  119.31595  POINT (13282190.798 -549474.605)

# %%
from matplotlib.patches import Circle

ZOOM = 35000 # In metres
SCALE_BAR_LEN = 20000 # in metries
SCALE_BAR_POS = {"lower left": (-0.00, 0.1)} # x and y, can set as negative vals if needed
RECORDER_COORDS: List[Tuple[float, float]] = [
    (-4.70878, 119.32657),  # A
    (-4.80363, 119.32858),  # B
    (-4.92992, 119.31595),  # C
    (-5.07711, 119.31749),  # D
]

def load_recorders() -> gpd.GeoDataFrame:
    """Create a GeoDataFrame from RECORDER_COORDS in WGS84 and project to Web Mercator."""
    df = pd.DataFrame(
        RECORDER_COORDS, columns=["Latitude", "Longitude"]
    )
    gdf = gpd.GeoDataFrame(
        df,
        geometry=gpd.points_from_xy(df.Longitude, df.Latitude),
        crs="EPSG:4326",
    )
    return gdf.to_crs(epsg=3857)

gdf = load_recorders()


# For a single point, set a default half-extent (e.g. 500 km) for a zoomed-out view
xmid = gdf[2:3].geometry.x.iloc[0]
ymid = gdf[2:3].geometry.y.iloc[0]
half_extent = ZOOM  # adjust as needed for Queensland's coast


square_xlim = (xmid - half_extent, xmid + half_extent)
square_ylim = (ymid - half_extent, ymid + half_extent)

# Create colours list based on the first letter of "new_name"
colours = ["black" if idx == 2 else "white" for idx in range(len(gdf))]

fig, ax = plt.subplots(figsize=(10, 10))

# Plot recorder points
gdf.plot(
    ax=ax,
    color=colours,
    markersize=40,
    edgecolor="black",
    linewidth=DOT_EDGE_WIDTH,
    zorder=5,
)

### Draw the radius 
# Draw a dashed red radius line at a 320° angle above horizontal
center = gdf[2:3].geometry.iloc[0]
radius_m = 16_950  # 16.95 km

x0, y0 = center.x, center.y
angle = np.deg2rad(0)          # tilt angle (in radians)
dx = radius_m * np.cos(angle)   # horizontal component
dy = radius_m * np.sin(angle)   # vertical component
x1, y1 = x0 + dx, y0 + dy

# plot the line
ax.plot([x0, x1], [y0, y1],
        color="grey",
        linestyle="--",
        linewidth=1)

# Label at the midpoint of the tilted line (and shift a bit left)
mid_x, mid_y = x0 + ((dx/2)+ 7000), (y0 +100) + dy/2
ax.text(mid_x, mid_y,
        "16.95 km",
        color="black",
        fontsize=18,
        ha="right",    # align text to the left of its anchor
        va="bottom")  # put text just above the line

# plot the circle
circle = Circle(
    (x0, y0),
    radius=radius_m,
    edgecolor="grey",
    facecolor="none",
    linestyle="--",
    linewidth=1.5,
    zorder=4  # slightly below the point markers
)
ax.add_patch(circle)
###


ax.set_xlim(square_xlim)
ax.set_ylim(square_ylim)
ax.set_aspect("equal", adjustable="box")

# Add a basemap
basemap_provider = ctx.providers.OpenStreetMap.CH
ctx.add_basemap(ax, source=basemap_provider)

# Add north arrow and scale bar (assumed defined elsewhere)
add_north_arrow(ax, location="lower right", zoom=0.05)
add_scalebar(ax, length=SCALE_BAR_LEN, pos_override=SCALE_BAR_POS)
ax.xaxis.set_ticks_position("bottom")
ax.yaxis.set_ticks_position("left")
ax.tick_params(axis="both", labelsize=18)
ax.xaxis.set_major_formatter(mticker.FuncFormatter(make_x_formatter(decimals=2)))
ax.yaxis.set_major_formatter(mticker.FuncFormatter(make_y_formatter(decimals=2)))
ticks = ax.get_xticks()
ax.set_xticks(ticks[::2])

plt.tight_layout()
save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", f"supp_map.png")
plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()

# %% [markdown]
# #### Map for inset context

# %%
from matplotlib.patches import Circle


MAP = 'indonesia_zoom_out'
ZOOM =2800000 # In metres
SCALE_BAR_LEN = 20000 # in metries
SCALE_BAR_POS = {"lower left": (-0.00, 0.1)} # x and y, can set as negative vals if needed

# Read CSV and create GeoDataFrame in EPSG:4326 then convert to EPSG:3857
df = pd.read_csv(os.path.join(BASE_DIR, "marrs_acoustics/data/figures/site_maps/" + MAP + ".csv"))
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df.Longitude, df.Latitude),
    crs="EPSG:4326"
)
gdf = gdf.to_crs(epsg=3857)

# Compute bounds with a buffer (in metres)
if len(gdf) == 1:
    # For a single point, set a default half-extent (e.g. 500 km) for a zoomed-out view
    xmid = gdf.geometry.x.iloc[0]
    ymid = gdf.geometry.y.iloc[0]
    half_extent = ZOOM  # adjust as needed for Queensland's coast
else:
    xmin, ymin, xmax, ymax = gdf.total_bounds
    xmin, ymin, xmax, ymax = xmin - BUFFER, ymin - BUFFER, xmax + BUFFER, ymax + BUFFER
    xmid = (xmin + xmax) / 2
    ymid = (ymin + ymax) / 2
    half_extent = max(xmax - xmin, ymax - ymin) / 2


square_xlim = (xmid - half_extent, xmid + half_extent)
square_ylim = (ymid - half_extent, ymid + half_extent)

# Create colours list based on the first letter of "new_name"
colors = [COLOUR_MAPPING.get(name[0], "black") for name in gdf["new_name"]]

fig, ax = plt.subplots(figsize=(10, 10))

# Plot points with a black outline
gdf.plot(
    ax=ax,
    color=colors,
    markersize=30,
    edgecolor="black",
    linewidth=DOT_EDGE_WIDTH,
    zorder=5,
)



ax.set_xlim(square_xlim)
ax.set_ylim(square_ylim)
ax.set_aspect("equal", adjustable="box")

# Add a basemap
basemap_provider = ctx.providers.OpenStreetMap.BZH #.BZH for no labels, .HOT for nice borders but has labels
ctx.add_basemap(ax, source=basemap_provider)

# Add north arrow and scale bar (assumed defined elsewhere)
#add_north_arrow(ax)
#add_scalebar(ax, length=SCALE_BAR_LEN, pos_override=SCALE_BAR_POS)
ax.xaxis.set_ticks_position("bottom")
ax.yaxis.set_ticks_position("left")
ax.tick_params(axis="both", labelsize=25)
ax.xaxis.set_major_formatter(mticker.FuncFormatter(make_x_formatter(decimals=1)))
ax.yaxis.set_major_formatter(mticker.FuncFormatter(make_y_formatter(decimals=1)))
ticks = ax.get_xticks()
ax.set_xticks(ticks[::2])

plt.tight_layout()
save_path = os.path.join(BASE_DIR, "bomb_fishing/data/figures", f"submap_label_free.png")
plt.savefig(save_path, dpi=600, bbox_inches="tight", transparent=True)
plt.show()
